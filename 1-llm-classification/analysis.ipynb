# %%
# !pip install pandas ir_datasets statsmodels krippendorff

# %%
import pandas as pd
import os

# %%
df = pd.read_csv("queries_annotation_all.csv")
df["query"] = df["query"].str.lower()

# %%
dir = "../data/processed/queries_annotation"
files = os.listdir(dir)

groups = {0: pd.DataFrame()}

for file in files:    
    print(file)
    if not file.endswith(".tsv"):
        continue
    annotations = pd.read_csv(f"{dir}/{file}", sep="\t")
        
    # Cleaning
    annotations = annotations.rename(columns={"1. Nicht Zeitlich": 1, "2. Explizit Zeitlich": 2, "3. Ereignis": 3, "4. Mehrdeutig": 4, "5. Aktualität": 5})
    annotations["query"] = annotations["query"].str.lower()
    annotations = annotations[annotations["query"]!="airport security"]  # duplicate topic
    try:
        annotations = annotations.drop(columns=["Notizen"])
    except:
        print(f"{file} has no notizen")

    # One-Hot Decoding
    annotations = pd.melt(annotations, id_vars=['query'], var_name='category', value_name='Value')
    annotations = annotations[annotations['Value'] == 1].drop(columns='Value').reset_index(drop=True)    
    
    annotations["annotator"] = file.split("_")[1].replace(".tsv", "")
    
    # Merge per group
    updated = False
    for key, group in groups.items():
        if group.empty:
            groups[key] = annotations.copy()
            updated = True
            break
        elif not group['query'].isin(annotations['query']).any():
            groups[key] = pd.concat([group, annotations], ignore_index=True)
            updated = True
            break

    if not updated:
        groups[key+1] = annotations.copy()
# Out:
# queries_jonina.tsv
# queries_braun.tsv
# queries_lin.tsv
# queries_large.tsv
# queries_mmoershe.tsv
# queries_loewenstein.tsv
# queries_maron.tsv
# .gitkeep
# queries_simon.tsv
# queries_romanovskis.tsv
# queries_romanovskis.tsv has no notizen
# README.md
# queries_ofunim.tsv
# queries_ofunim.tsv has no notizen
# queries_busch.tsv
# queries_coban.tsv
# queries_hovhannisyan.tsv
# queries_el_ghadioui.tsv
# queries_wollenberg.tsv
# queries_maassen.tsv
# queries_witalla.tsv

# %%
groups.keys()  # we have up to 5 annotators for one group
# Out:
# dict_keys([0, 1, 2, 3, 4])

# %%
table = groups[0][["query"]].set_index('query')

for id, group in groups.items():
    if key == 0:
        continue
    table = table.join(group.set_index('query').copy(), rsuffix=f"_{id}")

# %%
df_annotated = table.join(df.set_index("query"))

# %%
df_annotated.to_csv("queries_annotation_all_grouped.csv")

# %% [markdown]
# # Interrator Agreement

# %%
import pandas as pd
from statsmodels.stats.inter_rater import fleiss_kappa, aggregate_raters

# %%
df_annotated[["category", "category_1", "category_2"]].dropna()
# Out:
#                                category category_1 category_2
# query
# taxing social security                1          1          1
# term limits                           1          4          1
# potatoes                              1          1          1
# lyme disease arthritis                1          1          1
# international organized crime         1          4          1
# ...                                 ...        ...        ...
# control of mrsa                       4          1          5
# declining middle class in u.s.        4          5          5
# el nino                               4          5          5
# ethanol and food prices               5          5          5
# china one-child impact                5          1          1
#
# [428 rows x 3 columns]

# %%
rater_matrix = aggregate_raters(df_annotated[["category", "category_1", "category_2"]].dropna().values)

# %%
fleiss_kappa(rater_matrix[0])
# Out:
# np.float64(0.3303714504323723)

# %%
import krippendorff

# %%
krippendorff.alpha(value_counts=rater_matrix[0], level_of_measurement="nominal")
# Out:
# np.float64(0.330892967994341)

# %%
df_annotated
# Out:
#                                category    annotator category_1 annotator_1  \
# query
# taxing social security                1       jonina          1       maron
# term limits                           1       jonina          4       maron
# potatoes                              1       jonina          1       maron
# lyme disease arthritis                1       jonina          1       maron
# international organized crime         1       jonina          4       maron
# ...                                 ...          ...        ...         ...
# control of mrsa                       4  loewenstein          1       busch
# declining middle class in u.s.        4  loewenstein          5       busch
# el nino                               4  loewenstein          5       busch
# ethanol and food prices               5  loewenstein          5       busch
# china one-child impact                5  loewenstein          1       busch
#
#                                category_2 annotator_2 category_3 annotator_3  \
# query
# taxing social security                  1       coban        NaN         NaN
# term limits                             1       coban        NaN         NaN
# potatoes                                1       coban        NaN         NaN
# lyme disease arthritis                  1       coban        NaN         NaN
# international organized crime           1       coban        NaN         NaN
# ...                                   ...         ...        ...         ...
# control of mrsa                         5  wollenberg        NaN         NaN
# declining middle class in u.s.          5  wollenberg        NaN         NaN
# el nino                                 5  wollenberg        NaN         NaN
# ethanol and food prices                 5  wollenberg        NaN         NaN
# china one-child impact                  1  wollenberg        NaN         NaN
#
#                                category_4 annotator_4            id    dataset
# query
# taxing social security                NaN         NaN  608_robust04  Robust 04
# term limits                           NaN         NaN  699_robust04  Robust 04
# potatoes                              NaN         NaN    2_longeval   LongEval
# lyme disease arthritis                NaN         NaN  604_robust04  Robust 04
# international organized crime         NaN         NaN  301_robust04  Robust 04
# ...                                   ...         ...           ...        ...
# control of mrsa                       NaN         NaN    823_core18    Core 18
# declining middle class in u.s.        NaN         NaN    803_core18    Core 18
# el nino                               NaN         NaN  365_robust04  Robust 04
# ethanol and food prices               NaN         NaN    825_core18    Core 18
# china one-child impact                NaN         NaN    814_core18    Core 18
#
# [438 rows x 12 columns]
